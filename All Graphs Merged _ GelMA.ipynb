# %% [markdown]
# # All Merged_ Means

# %%
import pandas as pd

# %%
from sklearn import preprocessing
import seaborn as sns
from tabulate import tabulate

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Parameters and Data Import

# %%
#GelMA_Only_FS_Mean = pd.read_csv("1)GelMA_Only_FS_Mean.csv")
#GelMA_Only_SS_Mean = pd.read_csv("2)GelMA_Only_SS_Mean.csv")
#GelMA_Only_Error_FS = pd.read_csv("3)GelMA_Only_Error_FS.csv")

#GelMA_SMPEG2_FS_M = pd.read_csv("4)GelMA_SMPEG2_FS_M.csv")
#GelMA_SMPEG2_SS_M = pd.read_csv("5)GelMA_SMPEG2_SS_M.csv")
#GelMA_SMPEG2_Er = pd.read_csv("6)GelMA_SMPEG2_Er.csv")


#GelMA_DHR14_FS_M = pd.read_csv("7)GelMA_DHR14_FS_M.csv")
#GelMA_DHR14_SS_M = pd.read_csv("8)GelMA_DHR14_SS_M.csv")
#GelMA_DHR14_Er = pd.read_csv("9)GelMA_DHR14_Er.csv")

#GelMA_des04c1_FS_M = pd.read_csv("10)GelMA_des04c1_FS_M.csv")
#GelMA_des04c1_SS_M = pd.read_csv("11)GelMA_des04c1_SS_M.csv")
#GelMA_des04c1_Er = pd.read_csv("12)GelMA_des04c1_Er.csv")


#GelMA_des04c2_FS_M = pd.read_csv("13)GelMA_des04c2_FS_M.csv")
#GelMA_des04c2_SS_M = pd.read_csv("14)GelMA_des04c2_SS_M.csv")
#GelMA_des04c2_Er = pd.read_csv("15)GelMA_des04c2_Er.csv")


#GelMA_EGFP_FS_M = pd.read_csv("16)GelMA_EGFP_FS_M.csv")
#GelMA_EGFP_SS_M = pd.read_csv("17)GelMA_EGFP_SS_M.csv")
#GelMA_EGFP_Er = pd.read_csv("18)GelMA_EGFP_Er.csv")

# %%
F1_only = pd.read_csv("F1_only.csv")
Strk1_only = pd.read_csv("Strk1_only.csv")
S1_only = pd.read_csv("S1_only.csv")
Strn1_only = pd.read_csv("Strn1_only.csv")

F1_SMPEG2 = pd.read_csv("F1_SMPEG2.csv")
Strk1_SMPEG2 = pd.read_csv("Strk1_SMPEG2.csv")
S1_SMPEG2 = pd.read_csv("S1_SMPEG2.csv")
Strn1_SMPEG2 = pd.read_csv("Strn1_SMPEG2.csv")

F1_DHR14 = pd.read_csv("F1_DHR14.csv")
Strk1_DHR14 = pd.read_csv("Strk1_DHR14.csv")
S1_DHR14 = pd.read_csv("S1_DHR14.csv")
Strn1_DHR14 = pd.read_csv("Strn1_DHR14.csv")

F1_des04c1 = pd.read_csv("F1_des04c1.csv")
Strk1_des04c1 = pd.read_csv("Strk1_des04c1.csv")
S1_des04c1 = pd.read_csv("S1_des04c1.csv")
Strn1_des04c1 = pd.read_csv("Strn1_des04c1.csv")

F1_des04c2 = pd.read_csv("F1_des04c2.csv")
Strk1_des04c2 = pd.read_csv("Strk1_des04c2.csv")
S1_des04c2 = pd.read_csv("S1_des04c2.csv")
Strn1_des04c2 = pd.read_csv("Strn1_des04c2.csv")

F1_EGFP = pd.read_csv("F1_EGFP.csv")
Strk1_EGFP = pd.read_csv("Strk1_EGFP.csv")
S1_EGFP = pd.read_csv("S1_EGFP.csv")
Strn1_EGFP = pd.read_csv("Strn1_EGFP.csv")

# %%
F1_SMPEG2
# Out:
#        Unnamed: 0       Mean       Std     Error1     Error2
# 0               0   0.150124  0.000097   0.150027   0.150222
# 1               1   0.150633  0.000441   0.150192   0.151074
# 2               2   0.150617  0.000753   0.149864   0.151370
# 3               3   0.150665  0.000458   0.150207   0.151123
# 4               4   0.151825  0.000379   0.151445   0.152204
# ...           ...        ...       ...        ...        ...
# 11618       11618  34.098896  3.547462  30.551434  37.646358
# 11619       11619  34.110036  3.549115  30.560921  37.659151
# 11620       11620  34.121116  3.551028  30.570088  37.672144
# 11621       11621  34.131260  3.552398  30.578862  37.683658
# 11622       11622  34.138950  3.551296  30.587654  37.690246
#
# [11623 rows x 5 columns]

# %%
Strk1_EGFP
# Out:
#        Unnamed: 0      Mean       Std    Error1    Error2
# 0               0  0.000000  0.000000  0.000000  0.000000
# 1               1  0.000273  0.000202  0.000071  0.000475
# 2               2  0.001020  0.001052 -0.000032  0.002072
# 3               3  0.001173  0.001042  0.000131  0.002216
# 4               4  0.001493  0.000965  0.000529  0.002458
# ...           ...       ...       ...       ...       ...
# 14487       14487  2.415440  0.001097  2.414344  2.416537
# 14488       14488  2.415607  0.001096  2.414510  2.416703
# 14489       14489  2.415767  0.001103  2.414663  2.416870
# 14490       14490  2.415940  0.001102  2.414838  2.417041
# 14491       14491  2.416107  0.001102  2.415004  2.417209
#
# [14492 rows x 5 columns]

# %%
S1_EGFP
# Out:
#        Unnamed: 0       Mean        Std     Error1     Error2
# 0               0   0.363755   0.009625   0.354130   0.373380
# 1               1   0.364389   0.009622   0.354767   0.374011
# 2               2   0.366809   0.009644   0.357165   0.376453
# 3               3   0.369324   0.008694   0.360630   0.378019
# 4               4   0.370502   0.009803   0.360699   0.380306
# ...           ...        ...        ...        ...        ...
# 14487       14487  73.746252  17.058675  56.687577  90.804926
# 14488       14488  73.759618  17.059327  56.700291  90.818944
# 14489       14489  73.774014  17.059426  56.714588  90.833441
# 14490       14490  73.789877  17.060973  56.728904  90.850850
# 14491       14491  73.804354  17.064546  56.739808  90.868900
#
# [14492 rows x 5 columns]

# %% [markdown]
# # Plotting

# %% [markdown]
# ## All Force Stroke Data _ Means

# %%
#plt.plot(GelMA_Only_FS_Mean['GelMA Stroke Mean'],GelMA_Only_FS_Mean['GelMA Force Mean'],color = 'r')
#plt.plot(GelMA_SMPEG2_FS_M['GelMA Stroke Mean'],GelMA_SMPEG2_FS_M['GelMA Force Mean'],color = 'b')
#plt.plot(GelMA_DHR14_FS_M['GelMA Stroke Mean'],GelMA_DHR14_FS_M['GelMA Force Mean'],color = 'g')
#plt.plot(GelMA_des04c1_FS_M['GelMA Stroke Mean'],GelMA_des04c1_FS_M['GelMA Force Mean'],color = 'c')
#plt.plot(GelMA_des04c2_FS_M['GelMA Stroke Mean'],GelMA_des04c2_FS_M['GelMA Force Mean'],color = 'm')
##plt.plot(GelMA_EGFP_FS_M['GelMA Stroke Mean'],GelMA_EGFP_FS_M['GelMA Force Mean'],color = 'y')
#plt.grid()
#plt.legend('OSDd2E')
#plt.title('All GelMA Force Stroke Means')
#plt.xlabel('Stroke Normalised [mm]')
#plt.ylabel('Force [N]')
#plt.savefig("GelMA All_FS Mean.png")
#plt.show()

# %%
fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(111)

ax.plot(Strk1_only['Mean'], F1_only['Mean'], color= 'y', label = 'GelMA only')
ax.plot(Strk1_SMPEG2['Mean'], F1_SMPEG2['Mean'], color= 'k')
ax.plot(Strk1_DHR14['Mean'], F1_DHR14['Mean'], color= 'r')
ax.plot(Strk1_des04c1['Mean'], F1_des04c1['Mean'], color= 'm')
ax.plot(Strk1_des04c2['Mean'], F1_des04c2['Mean'], color= 'b')
ax.plot(Strk1_EGFP['Mean'], F1_EGFP['Mean'], color= 'g')


ymax1 = max(F1_only['Mean'])
xpos1 = list(F1_only['Mean']).index(ymax1)
xmax1 = Strk1_only['Mean'][xpos1]


ymax2 = max(F1_SMPEG2['Mean'])
xpos2 = list(F1_SMPEG2['Mean']).index(ymax2)
xmax2 = Strk1_SMPEG2['Mean'][xpos2]


ymax3 = max(F1_DHR14['Mean'])
xpos3 = list(F1_DHR14['Mean']).index(ymax3)
xmax3 = Strk1_DHR14['Mean'][xpos3]


ymax4 = max(F1_des04c1['Mean'])
xpos4 = list(F1_des04c1['Mean']).index(ymax4)
xmax4 = Strk1_des04c1['Mean'][xpos4]


ymax5 = max(F1_des04c2['Mean'])
xpos5 = list(F1_des04c2['Mean']).index(ymax5)
xmax5 = Strk1_des04c2['Mean'][xpos5]


ymax6 = max(F1_EGFP['Mean'])
xpos6 = list(F1_EGFP['Mean']).index(ymax6)
xmax6 = Strk1_EGFP['Mean'][xpos6]

#ax.annotate('x={:.2f}, y={:.2f}'.format(xmax1, ymax1), xy=(xmax1, ymax1), xytext=(xmax1-0.2, ymax1+0.4), color = 'y')
ax.annotate('{:.2f}'.format(ymax1), xy=(xmax1, ymax1), xytext=(xmax1-0.1, ymax1+0.4), color = 'y', size = 15)
ax.annotate('{:.2f}'.format(ymax2), xy=(xmax2, ymax2), xytext=(xmax2-0.1, ymax2+0.4), color = 'k', size = 15)
ax.annotate('{:.2f}'.format(ymax3), xy=(xmax3, ymax3), xytext=(xmax3-0.1, ymax3+0.4), color = 'r', size = 15)
ax.annotate('{:.2f}'.format(ymax4), xy=(xmax4, ymax4), xytext=(xmax4-0.1, ymax4+0.4), color = 'm', size = 15)
ax.annotate('{:.2f}'.format(ymax5), xy=(xmax5, ymax5), xytext=(xmax5+0.02, ymax5+0.4), color = 'b', size = 15)
ax.annotate('{:.2f}'.format(ymax6), xy=(xmax6, ymax6), xytext=(xmax6-0.15, ymax6+0.4), color = 'g', size = 15)

ax.legend('OSDd2E', loc = 'upper left')

plt.ylim(0,50)
plt.xlim(0,3.51)
ax.grid()
plt.title('All GelMA Force Stroke Means')
plt.xlabel('Stroke Normalised [mm]')
plt.ylabel('Force [N]')
#plt.savefig("GelMA All_FS Mean.png")
plt.show()

# %%
type(F1_only['Mean'])
# Out:
# pandas.core.series.Series

# %%
fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(111)

ax.plot(Strk1_only['Mean'], F1_only['Mean'], color= 'y', label = 'GelMA only')
ax.plot(Strk1_SMPEG2['Mean'], F1_SMPEG2['Mean'], color= 'k')
ax.plot(Strk1_DHR14['Mean'], F1_DHR14['Mean'], color= 'r')
ax.plot(Strk1_des04c1['Mean'], F1_des04c1['Mean'], color= 'm')
ax.plot(Strk1_des04c2['Mean'], F1_des04c2['Mean'], color= 'b')
ax.plot(Strk1_EGFP['Mean'], F1_EGFP['Mean'], color= 'g')

ymax1 = max(F1_only['Mean'])
xpos1 = list(F1_only['Mean']).index(ymax1)
xmax1 = Strk1_only['Mean'][xpos1]


ymax2 = max(F1_SMPEG2['Mean'])
xpos2 = list(F1_SMPEG2['Mean']).index(ymax2)
xmax2 = Strk1_SMPEG2['Mean'][xpos2]


ymax3 = max(F1_DHR14['Mean'])
xpos3 = list(F1_DHR14['Mean']).index(ymax3)
xmax3 = Strk1_DHR14['Mean'][xpos3]


ymax4 = max(F1_des04c1['Mean'])
xpos4 = list(F1_des04c1['Mean']).index(ymax4)
xmax4 = Strk1_des04c1['Mean'][xpos4]


ymax5 = max(F1_des04c2['Mean'])
xpos5 = list(F1_des04c2['Mean']).index(ymax5)
xmax5 = Strk1_des04c2['Mean'][xpos5]


ymax6 = max(F1_EGFP['Mean'])
xpos6 = list(F1_EGFP['Mean']).index(ymax6)
xmax6 = Strk1_EGFP['Mean'][xpos6]

#ax.annotate('x={:.2f}, y={:.2f}'.format(xmax1, ymax1), xy=(xmax1, ymax1), xytext=(xmax1-0.2, ymax1+0.4), color = 'y')
#ax.annotate('x={:.2f}, y={:.2f}'.format(xmax2, ymax2), xy=(xmax2, ymax2), xytext=(xmax2-0.2, ymax2+0.4), color = 'k')
#ax.annotate('x={:.2f}, y={:.2f}'.format(xmax3, ymax3), xy=(xmax3, ymax3), xytext=(xmax3-0.2, ymax3+0.4), color = 'r')
#ax.annotate('x={:.2f}, y={:.2f}'.format(xmax4, ymax4), xy=(xmax4, ymax4), xytext=(xmax4-0.2, ymax4+0.4), color = 'm')
#ax.annotate('x={:.2f}, y={:.2f}'.format(xmax5, ymax5), xy=(xmax5, ymax5), xytext=(xmax5-0.2, ymax5+0.4), color = 'b')
#ax.annotate('x={:.2f}, y={:.2f}'.format(xmax6, ymax6), xy=(xmax6, ymax6), xytext=(xmax6-0.2, ymax6+0.4), color = 'g')


plt.legend('OSDd2E', loc = 'upper left')

ax.fill_between(Strk1_only['Mean'], F1_only['Error1'], F1_only['Error2'], color= 'y', alpha = 0.2)
ax.fill_between(Strk1_SMPEG2['Mean'], F1_SMPEG2['Error1'], F1_SMPEG2['Error2'], color= 'k', alpha = 0.2)
ax.fill_between(Strk1_DHR14['Mean'], F1_DHR14['Error1'], F1_DHR14['Error2'], color= 'r', alpha = 0.2)
ax.fill_between(Strk1_des04c1['Mean'], F1_des04c1['Error1'], F1_des04c1['Error2'], color= 'm', alpha = 0.2)
ax.fill_between(Strk1_des04c2['Mean'], F1_des04c2['Error1'], F1_des04c2['Error2'], color= 'b', alpha = 0.2)
ax.fill_between(Strk1_EGFP['Mean'], F1_EGFP['Error1'], F1_EGFP['Error2'], color= 'g', alpha = 0.2)


plt.ylim(0,50)
plt.xlim(0,3.51)
plt.grid()
plt.title('All GelMA Force Stroke Means')
plt.xlabel('Stroke Normalised [mm]')
plt.ylabel('Force [N]')
#plt.savefig("GelMA All_FS Mean_error.png")
plt.show()

# %% [markdown]
# ## All Stress Strain Data _ Means

# %%
#plt.plot(GelMA_Only_SS_Mean['GelMA Stroke Mean'],GelMA_Only_SS_Mean['GelMA Force Mean'],color = 'r')
#plt.plot(GelMA_SMPEG2_SS_M['GelMA Stroke Mean'],GelMA_SMPEG2_SS_M['GelMA Force Mean'],color = 'b')
#plt.plot(GelMA_DHR14_SS_M['GelMA Stroke Mean'],GelMA_DHR14_SS_M['GelMA Force Mean'],color = 'g')
#plt.plot(GelMA_des04c1_SS_M['GelMA Stroke Mean'],GelMA_des04c1_SS_M['GelMA Force Mean'],color = 'c')
#plt.plot(GelMA_des04c2_SS_M['GelMA Stroke Mean'],GelMA_des04c2_SS_M['GelMA Force Mean'],color = 'm')
#plt.plot(GelMA_EGFP_SS_M['GelMA Stroke Mean'],GelMA_EGFP_SS_M['GelMA Force Mean'],color = 'y')
#plt.grid()
#plt.legend('OSDd2E')
#plt.title('All GelMA Stress Strain Means')
#plt.xlabel('Strain Normalised')
#plt.ylabel('Stress [Pa]')
#plt.savefig("GelMA All_SS Mean.png")
#plt.show()

# %%
fig = plt.figure(figsize=(15, 10))
ax1 = fig.add_subplot(111)

ax1.plot(Strn1_only['Mean'], S1_only['Mean'], color= 'y', label = 'GelMA only')

ax1.plot(Strn1_SMPEG2['Mean'], S1_SMPEG2['Mean'], color= 'k')
ax1.plot(Strn1_DHR14['Mean'], S1_DHR14['Mean'], color= 'r')
ax1.plot(Strn1_des04c1['Mean'], S1_des04c1['Mean'], color= 'm')
ax1.plot(Strn1_des04c2['Mean'], S1_des04c2['Mean'], color= 'b')
ax1.plot(Strn1_EGFP['Mean'], S1_EGFP['Mean'], color= 'g')

ymax7 = max(S1_only['Mean'])
xpos7 = list(S1_only['Mean']).index(ymax7)
xmax7 = Strn1_only['Mean'][xpos7]


ymax8 = max(S1_SMPEG2['Mean'])
xpos8 = list(S1_SMPEG2['Mean']).index(ymax8)
xmax8 = Strn1_SMPEG2['Mean'][xpos8]


ymax9 = max(S1_DHR14['Mean'])
xpos9 = list(S1_DHR14['Mean']).index(ymax9)
xmax9 = Strn1_DHR14['Mean'][xpos9]


ymax10 = max(S1_des04c1['Mean'])
xpos10 = list(S1_des04c1['Mean']).index(ymax10)
xmax10 = Strn1_des04c1['Mean'][xpos10]


ymax11 = max(S1_des04c2['Mean'])
xpos11 = list(S1_des04c2['Mean']).index(ymax11)
xmax11 = Strn1_des04c2['Mean'][xpos11]


ymax12 = max(S1_EGFP['Mean'])
xpos12 = list(S1_EGFP['Mean']).index(ymax12)
xmax12 = Strn1_EGFP['Mean'][xpos12]

#ax1.annotate('x={:.2f}, y={:.2f}'.format(xmax7, ymax7), xy=(xmax7, ymax7), xytext=(xmax7-0.03, ymax7+3000), color = 'y')
ax1.annotate('{:.2f}'.format(ymax7), xy=(xmax7, ymax7), xytext=(xmax7-0, ymax7+0), color = 'y', size = 15)
ax1.annotate('{:.2f}'.format(ymax8), xy=(xmax8, ymax8), xytext=(xmax8-0, ymax8+0), color = 'k', size = 15)
ax1.annotate('{:.2f}'.format(ymax9), xy=(xmax9, ymax9), xytext=(xmax9-0.02, ymax9+0), color = 'r', size = 15)
ax1.annotate('{:.2f}'.format(ymax10), xy=(xmax10, ymax10), xytext=(xmax10-0, ymax10+0), color = 'm', size = 15)
ax1.annotate('{:.2f}'.format(ymax11), xy=(xmax11, ymax11), xytext=(xmax11-0, ymax11+0), color = 'b', size = 15)
ax1.annotate('{:.2f}'.format(ymax12), xy=(xmax12, ymax12), xytext=(xmax12-0, ymax12+0), color = 'g', size = 15)



plt.legend('OSDd2E', loc = 'upper left')

plt.ylim(0,220)
plt.xlim(0,0.61)
ax1.grid()
plt.title('All GelMA Stress Strain Means')
plt.xlabel('Strain Normalised')
plt.ylabel('Stress [kPa]')
#plt.savefig("GelMA All_SS Mean.png")
plt.show()

# %%
fig = plt.figure(figsize=(15, 10))
ax1 = fig.add_subplot(111)

ax1.plot(Strn1_only['Mean'], S1_only['Mean'], color= 'y', label = 'GelMA only')

ax1.plot(Strn1_SMPEG2['Mean'], S1_SMPEG2['Mean'], color= 'k')
ax1.plot(Strn1_DHR14['Mean'], S1_DHR14['Mean'], color= 'r')
ax1.plot(Strn1_des04c1['Mean'], S1_des04c1['Mean'], color= 'm')
ax1.plot(Strn1_des04c2['Mean'], S1_des04c2['Mean'], color= 'b')
ax1.plot(Strn1_EGFP['Mean'], S1_EGFP['Mean'], color= 'g')

ymax7 = max(S1_only['Mean'])
xpos7 = list(S1_only['Mean']).index(ymax7)
xmax7 = Strn1_only['Mean'][xpos7]


ymax8 = max(S1_SMPEG2['Mean'])
xpos8 = list(S1_SMPEG2['Mean']).index(ymax8)
xmax8 = Strn1_SMPEG2['Mean'][xpos8]


ymax9 = max(S1_DHR14['Mean'])
xpos9 = list(S1_DHR14['Mean']).index(ymax9)
xmax9 = Strn1_DHR14['Mean'][xpos9]


ymax10 = max(S1_des04c1['Mean'])
xpos10 = list(S1_des04c1['Mean']).index(ymax10)
xmax10 = Strn1_des04c1['Mean'][xpos10]


ymax11 = max(S1_des04c2['Mean'])
xpos11 = list(S1_des04c2['Mean']).index(ymax11)
xmax11 = Strn1_des04c2['Mean'][xpos11]


ymax12 = max(S1_EGFP['Mean'])
xpos12 = list(S1_EGFP['Mean']).index(ymax12)
xmax12 = Strn1_EGFP['Mean'][xpos12]

#ax1.annotate('x={:.2f}, y={:.2f}'.format(xmax7, ymax7), xy=(xmax7, ymax7), xytext=(xmax7-0.03, ymax7+3000), color = 'y')
#ax1.annotate('x={:.2f}, y={:.2f}'.format(xmax8, ymax8), xy=(xmax8, ymax8), xytext=(xmax8-0.03, ymax8+3000), color = 'k')
#ax1.annotate('x={:.2f}, y={:.2f}'.format(xmax9, ymax9), xy=(xmax9, ymax9), xytext=(xmax9-0.03, ymax9+3000), color = 'r')
#ax1.annotate('x={:.2f}, y={:.2f}'.format(xmax10, ymax10), xy=(xmax10, ymax10), xytext=(xmax10-0.03, ymax10+3000), color = 'm')
#ax1.annotate('x={:.2f}, y={:.2f}'.format(xmax11, ymax11), xy=(xmax11, ymax11), xytext=(xmax11-0.03, ymax11+3000), color = 'b')
#ax1.annotate('x={:.2f}, y={:.2f}'.format(xmax12, ymax12), xy=(xmax12, ymax12), xytext=(xmax12-0.03, ymax12+3000), color = 'g')



plt.legend('OSDd2E', loc = 'upper left')

ax1.fill_between(Strn1_only['Mean'], S1_only['Error1'], S1_only['Error2'], color= 'y', alpha = 0.4)

ax1.fill_between(Strn1_SMPEG2['Mean'], S1_SMPEG2['Error1'], S1_SMPEG2['Error2'], color= 'k', alpha = 0.2)

ax1.fill_between(Strn1_DHR14['Mean'], S1_DHR14['Error1'], S1_DHR14['Error2'], color= 'r', alpha = 0.2)

ax1.fill_between(Strn1_des04c1['Mean'], S1_des04c1['Error1'], S1_des04c1['Error2'], color= 'm', alpha = 0.2)

ax1.fill_between(Strn1_des04c2['Mean'], S1_des04c2['Error1'], S1_des04c2['Error2'], color= 'b', alpha = 0.2)

ax1.fill_between(Strn1_EGFP['Mean'], S1_EGFP['Error1'], S1_EGFP['Error2'], color= 'g', alpha = 0.2)


plt.grid()
#plt.ylim(0,220000)
plt.ylim(0,220)
plt.xlim(0,0.61)
plt.title('All GelMA Stress Strain Means')
plt.xlabel('Strain Normalised')
plt.ylabel('Stress [kPa]')
#plt.savefig("GelMA All_SS Mean_error.png")
plt.show()

# %% [markdown]
# ## All Force Stroke Data _ Means & Errors

# %%
#plt.plot(GelMA_Only_FS_Mean['GelMA Stroke Mean'],GelMA_Only_FS_Mean['GelMA Force Mean'],color = 'r')
#plt.plot(GelMA_SMPEG2_FS_M['GelMA Stroke Mean'],GelMA_SMPEG2_FS_M['GelMA Force Mean'],color = 'b')
#plt.plot(GelMA_DHR14_FS_M['GelMA Stroke Mean'],GelMA_DHR14_FS_M['GelMA Force Mean'],color = 'g')
#plt.plot(GelMA_des04c1_FS_M['GelMA Stroke Mean'],GelMA_des04c1_FS_M['GelMA Force Mean'],color = 'c')
#plt.plot(GelMA_des04c2_FS_M['GelMA Stroke Mean'],GelMA_des04c2_FS_M['GelMA Force Mean'],color = 'm')
#plt.plot(GelMA_EGFP_FS_M['GelMA Stroke Mean'],GelMA_EGFP_FS_M['GelMA Force Mean'],color = 'y')

#plt.errorbar(GelMA_Only_FS_Mean['GelMA Stroke Mean'],GelMA_Only_FS_Mean['GelMA Force Mean'], yerr = GelMA_Only_Error_FS['GelMA Error Margin'], fmt = ' ', color = 'r')
#plt.errorbar(GelMA_SMPEG2_FS_M['GelMA Stroke Mean'],GelMA_SMPEG2_FS_M['GelMA Force Mean'], yerr = GelMA_SMPEG2_Er['GelMA Error Margin'], fmt = ' ', color = 'b')
#plt.errorbar(GelMA_DHR14_FS_M['GelMA Stroke Mean'],GelMA_DHR14_FS_M['GelMA Force Mean'], yerr = GelMA_DHR14_Er['GelMA Error Margin'], fmt = ' ', color = 'g')
#plt.errorbar(GelMA_des04c1_FS_M['GelMA Stroke Mean'],GelMA_des04c1_FS_M['GelMA Force Mean'], yerr = GelMA_des04c1_Er['GelMA Error Margin'], fmt = ' ', color = 'c')
#plt.errorbar(GelMA_des04c2_FS_M['GelMA Stroke Mean'],GelMA_des04c2_FS_M['GelMA Force Mean'], yerr = GelMA_des04c2_Er['GelMA Error Margin'], fmt = ' ', color = 'm')
#plt.errorbar(GelMA_EGFP_FS_M['GelMA Stroke Mean'],GelMA_EGFP_FS_M['GelMA Force Mean'], yerr = GelMA_EGFP_Er['GelMA Error Margin'], fmt = ' ', color = 'y')

#plt.grid()
#plt.legend('OSDd2E')
#plt.title('All GelMA Force vs Stroke Mean & Error Margin')
#plt.xlabel('Stroke Normalised [mm]')
#plt.ylabel('Force [N]')
#plt.savefig("GelMA All_FS Mean_Error.png")
#plt.show()

# %% [markdown]
# ## All Stress Strain Data _ Means & Errors

# %% [markdown]
# ## Fill under the curve

# %% [markdown]
# ### All Force Stroke Data _ Means

# %%
#plt.plot(GelMA_Only_FS_Mean['GelMA Stroke Mean'],GelMA_Only_FS_Mean['GelMA Force Mean'],color = 'r')
#plt.plot(GelMA_SMPEG2_FS_M['GelMA Stroke Mean'],GelMA_SMPEG2_FS_M['GelMA Force Mean'],color = 'b')
#plt.plot(GelMA_DHR14_FS_M['GelMA Stroke Mean'],GelMA_DHR14_FS_M['GelMA Force Mean'],color = 'g')
#plt.plot(GelMA_des04c1_FS_M['GelMA Stroke Mean'],GelMA_des04c1_FS_M['GelMA Force Mean'],color = 'c')
#plt.plot(GelMA_des04c2_FS_M['GelMA Stroke Mean'],GelMA_des04c2_FS_M['GelMA Force Mean'],color = 'm')
#plt.plot(GelMA_EGFP_FS_M['GelMA Stroke Mean'],GelMA_EGFP_FS_M['GelMA Force Mean'],color = 'y')

#plt.fill_between(GelMA_Only_FS_Mean['GelMA Stroke Mean'],GelMA_Only_FS_Mean['GelMA Force Mean'],color = 'r', alpha=0.5)
#plt.fill_between(GelMA_SMPEG2_FS_M['GelMA Stroke Mean'],GelMA_SMPEG2_FS_M['GelMA Force Mean'],color = 'b', alpha=0.5)
#plt.fill_between(GelMA_DHR14_FS_M['GelMA Stroke Mean'],GelMA_DHR14_FS_M['GelMA Force Mean'],color = 'g', alpha=0.5)
#plt.fill_between(GelMA_des04c1_FS_M['GelMA Stroke Mean'],GelMA_des04c1_FS_M['GelMA Force Mean'],color = 'c', alpha=0.5)
#plt.fill_between(GelMA_des04c2_FS_M['GelMA Stroke Mean'],GelMA_des04c2_FS_M['GelMA Force Mean'],color = 'm', alpha=0.5)
#plt.fill_between(GelMA_EGFP_FS_M['GelMA Stroke Mean'],GelMA_EGFP_FS_M['GelMA Force Mean'],color = 'y', alpha=0.5)

#plt.grid()
#plt.legend('OSDd2E')
#plt.title('All GelMA Force Stroke Means')
#plt.xlabel('Stroke Normalised [mm]')
#plt.ylabel('Force [N]')
#plt.savefig("GelMA All_FS_AUC.png")
#plt.show()

# %%
#F1_only
#Strk1_only


plt.plot(Strk1_only['Mean'], F1_only['Mean'], color= 'y')
plt.plot(Strk1_SMPEG2['Mean'], F1_SMPEG2['Mean'], color= 'k')
plt.plot(Strk1_DHR14['Mean'], F1_DHR14['Mean'], color= 'r')
plt.plot(Strk1_des04c1['Mean'], F1_des04c1['Mean'], color= 'm')
plt.plot(Strk1_des04c2['Mean'], F1_des04c2['Mean'], color= 'b')
plt.plot(Strk1_EGFP['Mean'], F1_EGFP['Mean'], color= 'g')

plt.fill_between(Strk1_only['Mean'], F1_only['Mean'], color= 'y', alpha=0.2)
plt.fill_between(Strk1_SMPEG2['Mean'], F1_SMPEG2['Mean'], color= 'k', alpha=0.2)
plt.fill_between(Strk1_DHR14['Mean'], F1_DHR14['Mean'], color= 'r', alpha=0.2)
plt.fill_between(Strk1_des04c1['Mean'], F1_des04c1['Mean'], color= 'm', alpha=0.2)
plt.fill_between(Strk1_des04c2['Mean'], F1_des04c2['Mean'], color= 'b', alpha=0.2)
plt.fill_between(Strk1_EGFP['Mean'], F1_EGFP['Mean'], color= 'g', alpha=0.2)


plt.grid()
plt.legend('OSDd2E')
plt.title('All GelMA Force Stroke Means')
plt.xlabel('Stroke Normalised [mm]')
plt.ylabel('Force [N]')
#plt.savefig("GelMA All_FS_AUC.png")
plt.show()

# %% [markdown]
# ### Smooth graph FS

# %%
#from scipy.ndimage.filters import gaussian_filter1d

#force_moving_avrg_O = gaussian_filter1d(GelMA_Only_FS_Mean['GelMA Force Mean'], sigma=50)#r
#force_moving_avrg_S = gaussian_filter1d(GelMA_SMPEG2_FS_M['GelMA Force Mean'], sigma=20)#b
#force_moving_avrg_D = gaussian_filter1d(GelMA_DHR14_FS_M['GelMA Force Mean'], sigma=280)#g
#force_moving_avrg_d = gaussian_filter1d(GelMA_des04c1_FS_M['GelMA Force Mean'], sigma=400)#c
#force_moving_avrg_2 = gaussian_filter1d(GelMA_des04c2_FS_M['GelMA Force Mean'], sigma=5)#m
#force_moving_avrg_E = gaussian_filter1d(GelMA_EGFP_FS_M['GelMA Force Mean'], sigma=500)#y

#plt.plot(GelMA_Only_FS_Mean['GelMA Stroke Mean'],force_moving_avrg_O,color='r')

#plt.plot(GelMA_SMPEG2_FS_M['GelMA Stroke Mean'],force_moving_avrg_S,color='b')

#plt.plot(GelMA_DHR14_FS_M['GelMA Stroke Mean'],force_moving_avrg_D,color='g')

#plt.plot(GelMA_des04c1_FS_M['GelMA Stroke Mean'],force_moving_avrg_d,color='c')

#plt.plot(GelMA_des04c2_FS_M['GelMA Stroke Mean'],force_moving_avrg_2,color='m')

#plt.plot(GelMA_EGFP_FS_M['GelMA Stroke Mean'],force_moving_avrg_E,color='y')

#plt.grid()
#plt.legend('OSDd2E')
#plt.title('All GelMA Force Stroke Means _ Smoothed')
#plt.xlabel('Stroke Normalised [mm]')
#plt.ylabel('Force [N]')
#plt.savefig("GelMA All_FS_Smoothed.png")
#plt.show()

# %%
#from scipy.ndimage.filters import gaussian_filter1d

#force_moving_avrg_O = gaussian_filter1d(GelMA_Only_FS_Mean['GelMA Force Mean'], sigma=50)#r
#force_moving_avrg_S = gaussian_filter1d(GelMA_SMPEG2_FS_M['GelMA Force Mean'], sigma=20)#b
#force_moving_avrg_D = gaussian_filter1d(GelMA_DHR14_FS_M['GelMA Force Mean'], sigma=280)#g
#force_moving_avrg_d = gaussian_filter1d(GelMA_des04c1_FS_M['GelMA Force Mean'], sigma=400)#c
#force_moving_avrg_2 = gaussian_filter1d(GelMA_des04c2_FS_M['GelMA Force Mean'], sigma=5)#m
#force_moving_avrg_E = gaussian_filter1d(GelMA_EGFP_FS_M['GelMA Force Mean'], sigma=500)#y

#plt.plot(GelMA_Only_FS_Mean['GelMA Stroke Mean'],force_moving_avrg_O,color='r')

#plt.plot(GelMA_SMPEG2_FS_M['GelMA Stroke Mean'],force_moving_avrg_S,color='b')

#plt.plot(GelMA_DHR14_FS_M['GelMA Stroke Mean'],force_moving_avrg_D,color='g')

#plt.plot(GelMA_des04c1_FS_M['GelMA Stroke Mean'],force_moving_avrg_d,color='c')

#plt.plot(GelMA_des04c2_FS_M['GelMA Stroke Mean'],force_moving_avrg_2,color='m')

#plt.plot(GelMA_EGFP_FS_M['GelMA Stroke Mean'],force_moving_avrg_E,color='y')

#plt.fill_between(GelMA_Only_FS_Mean['GelMA Stroke Mean'],force_moving_avrg_O,color = 'r', alpha=0.5)
#plt.fill_between(GelMA_SMPEG2_FS_M['GelMA Stroke Mean'],force_moving_avrg_S,color = 'b', alpha=0.5)
#plt.fill_between(GelMA_DHR14_FS_M['GelMA Stroke Mean'],force_moving_avrg_D,color = 'g', alpha=0.5)
#plt.fill_between(GelMA_des04c1_FS_M['GelMA Stroke Mean'],force_moving_avrg_d,color = 'c', alpha=0.5)
#plt.fill_between(GelMA_des04c2_FS_M['GelMA Stroke Mean'],force_moving_avrg_2,color = 'm', alpha=0.5)
#plt.fill_between(GelMA_EGFP_FS_M['GelMA Stroke Mean'],force_moving_avrg_E,color = 'y', alpha=0.5)

#plt.grid()
#plt.legend('OSDd2E')
#plt.title('All GelMA Force Stroke Means _ Smoothed')
#plt.xlabel('Stroke Normalised [mm]')
#plt.ylabel('Force [N]')
#plt.savefig("GelMA All_FS_AUC_Smoothed.png")
#plt.show()

# %% [markdown]
# ### All Stress Strain Data _ Means

# %%
#plt.plot(GelMA_Only_SS_Mean['GelMA Stroke Mean'].mean(),GelMA_Only_SS_Mean['GelMA Force Mean'].mean(),color = 'r')
#plt.plot(GelMA_SMPEG2_SS_M['GelMA Stroke Mean'],GelMA_SMPEG2_SS_M['GelMA Force Mean'],color = 'b')
#plt.plot(GelMA_DHR14_SS_M['GelMA Stroke Mean'],GelMA_DHR14_SS_M['GelMA Force Mean'],color = 'g')
#plt.plot(GelMA_des04c1_SS_M['GelMA Stroke Mean'],GelMA_des04c1_SS_M['GelMA Force Mean'],color = 'c')
#plt.plot(GelMA_des04c2_SS_M['GelMA Stroke Mean'],GelMA_des04c2_SS_M['GelMA Force Mean'],color = 'm')
#plt.plot(GelMA_EGFP_SS_M['GelMA Stroke Mean'],GelMA_EGFP_SS_M['GelMA Force Mean'],color = 'y')


#plt.fill_between(GelMA_SMPEG2_SS_M['GelMA Stroke Mean'],GelMA_SMPEG2_SS_M['GelMA Force Mean'],color = 'b', alpha=0.5)
#plt.fill_between(GelMA_DHR14_SS_M['GelMA Stroke Mean'],GelMA_DHR14_SS_M['GelMA Force Mean'],color = 'g', alpha=0.5)
#plt.fill_between(GelMA_des04c1_SS_M['GelMA Stroke Mean'],GelMA_des04c1_SS_M['GelMA Force Mean'],color = 'c', alpha=0.5)
#plt.fill_between(GelMA_des04c2_SS_M['GelMA Stroke Mean'],GelMA_des04c2_SS_M['GelMA Force Mean'],color = 'm', alpha=0.5)
#plt.fill_between(GelMA_Only_SS_Mean['GelMA Stroke Mean'],GelMA_Only_SS_Mean['GelMA Force Mean'],color = 'r', alpha=0.5)
#plt.fill_between(GelMA_EGFP_SS_M['GelMA Stroke Mean'],GelMA_EGFP_SS_M['GelMA Force Mean'],color = 'y', alpha=0.5)

#plt.grid()
#plt.legend('OSDd2E')
#plt.title('All GelMA Stress Strain Means')
#plt.xlabel('Strain Normalised')
#plt.ylabel('Stress [Pa]')
#plt.savefig("GelMA All_SS_AUC.png")
#plt.show()

# %%
#S1_only
#Strn1_only

plt.plot(Strn1_only['Mean'], S1_only['Mean'], color= 'y')
plt.plot(Strn1_SMPEG2['Mean'], S1_SMPEG2['Mean'], color= 'k')
plt.plot(Strn1_DHR14['Mean'], S1_DHR14['Mean'], color= 'r')
plt.plot(Strn1_des04c1['Mean'], S1_des04c1['Mean'], color= 'm')
plt.plot(Strn1_des04c2['Mean'], S1_des04c2['Mean'], color= 'b')
plt.plot(Strn1_EGFP['Mean'], S1_EGFP['Mean'], color= 'g')

plt.fill_between(Strn1_only['Mean'], S1_only['Mean'], color= 'y', alpha=0.5)
plt.fill_between(Strn1_SMPEG2['Mean'], S1_SMPEG2['Mean'], color= 'k', alpha=0.1)
plt.fill_between(Strn1_DHR14['Mean'], S1_DHR14['Mean'], color= 'r', alpha=0.1)
plt.fill_between(Strn1_des04c1['Mean'], S1_des04c1['Mean'], color= 'm', alpha=0.1)
plt.fill_between(Strn1_des04c2['Mean'], S1_des04c2['Mean'], color= 'b', alpha=0.1)
plt.fill_between(Strn1_EGFP['Mean'], S1_EGFP['Mean'], color= 'g', alpha=0.3)

plt.grid()
plt.legend('OSDd2E')
plt.title('All GelMA Stress Strain Means')
plt.xlabel('Strain Normalised')
plt.ylabel('Stress [kPa]')
#plt.savefig("GelMA All_SS_AUC.png")
plt.show()

# %%
#plt.plot(GelMA_Only_SS_Mean['GelMA Stroke Mean'],GelMA_Only_SS_Mean['GelMA Force Mean'],color = 'r')
#plt.fill_between(GelMA_Only_SS_Mean['GelMA Stroke Mean'],GelMA_Only_SS_Mean['GelMA Force Mean'],color = 'lightblue', alpha=0.5)

#plt.grid()
#plt.legend('O')
#plt.title('All GelMA Stress Strain Means')
#plt.xlabel('Strain Normalised')
#plt.ylabel('Stress [Pa]')
#plt.savefig("GelMA EGFP_FS_Non-max-cut.png")
#plt.show()

# %% [markdown]
# ### Smooth graph SS

# %%
#from scipy.ndimage.filters import gaussian_filter1d

#stress_moving_avrg_O = gaussian_filter1d(GelMA_Only_SS_Mean['GelMA Force Mean'], sigma=50)#r
#stress_moving_avrg_S = gaussian_filter1d(GelMA_SMPEG2_SS_M['GelMA Force Mean'], sigma=20)#b
#stress_moving_avrg_D = gaussian_filter1d(GelMA_DHR14_SS_M['GelMA Force Mean'], sigma=200)#g
#stress_moving_avrg_d = gaussian_filter1d(GelMA_des04c1_SS_M['GelMA Force Mean'], sigma=300)#c
#stress_moving_avrg_2 = gaussian_filter1d(GelMA_des04c2_SS_M['GelMA Force Mean'], sigma=100)#m
#stress_moving_avrg_E = gaussian_filter1d(GelMA_EGFP_SS_M['GelMA Force Mean'], sigma=500)#y

#plt.plot(GelMA_Only_SS_Mean['GelMA Stroke Mean'],stress_moving_avrg_O,color='r')

#plt.plot(GelMA_SMPEG2_SS_M['GelMA Stroke Mean'],stress_moving_avrg_S,color='b')

#plt.plot(GelMA_DHR14_SS_M['GelMA Stroke Mean'],stress_moving_avrg_D,color='g')

#plt.plot(GelMA_des04c1_SS_M['GelMA Stroke Mean'],stress_moving_avrg_d,color='c')

#plt.plot(GelMA_des04c2_SS_M['GelMA Stroke Mean'],stress_moving_avrg_2,color='m')

#plt.plot(GelMA_EGFP_SS_M['GelMA Stroke Mean'],stress_moving_avrg_E,color='y')

#plt.grid()
#plt.legend('OSDd2E')
#plt.title('All GelMA Stress Strain Means _ Smoothed')
#plt.xlabel('Strain Normalised')
#plt.ylabel('Stress [Pa]')
#plt.savefig("GelMA All_SS_Smoothed.png")
#plt.show()

# %%
#from scipy.ndimage.filters import gaussian_filter1d

#stress_moving_avrg_O = gaussian_filter1d(GelMA_Only_SS_Mean['GelMA Force Mean'], sigma=50)#r
#stress_moving_avrg_S = gaussian_filter1d(GelMA_SMPEG2_SS_M['GelMA Force Mean'], sigma=20)#b
#stress_moving_avrg_D = gaussian_filter1d(GelMA_DHR14_SS_M['GelMA Force Mean'], sigma=200)#g
#stress_moving_avrg_d = gaussian_filter1d(GelMA_des04c1_SS_M['GelMA Force Mean'], sigma=300)#c
#stress_moving_avrg_2 = gaussian_filter1d(GelMA_des04c2_SS_M['GelMA Force Mean'], sigma=100)#m
#stress_moving_avrg_E = gaussian_filter1d(GelMA_EGFP_SS_M['GelMA Force Mean'], sigma=500)#y

#plt.plot(GelMA_Only_SS_Mean['GelMA Stroke Mean'],stress_moving_avrg_O,color='r')

#plt.plot(GelMA_SMPEG2_SS_M['GelMA Stroke Mean'],stress_moving_avrg_S,color='b')

#plt.plot(GelMA_DHR14_SS_M['GelMA Stroke Mean'],stress_moving_avrg_D,color='g')

#plt.plot(GelMA_des04c1_SS_M['GelMA Stroke Mean'],stress_moving_avrg_d,color='c')

#plt.plot(GelMA_des04c2_SS_M['GelMA Stroke Mean'],stress_moving_avrg_2,color='m')

#plt.plot(GelMA_EGFP_SS_M['GelMA Stroke Mean'],stress_moving_avrg_E,color='y')


#plt.fill_between(GelMA_SMPEG2_SS_M['GelMA Stroke Mean'],stress_moving_avrg_S,color = 'b', alpha=0.5)
#plt.fill_between(GelMA_DHR14_SS_M['GelMA Stroke Mean'],stress_moving_avrg_D,color = 'g', alpha=0.5)
#plt.fill_between(GelMA_des04c1_SS_M['GelMA Stroke Mean'],stress_moving_avrg_d,color = 'c', alpha=0.5)
#plt.fill_between(GelMA_des04c2_SS_M['GelMA Stroke Mean'],stress_moving_avrg_2,color = 'm', alpha=0.5)
#plt.fill_between(GelMA_Only_SS_Mean['GelMA Stroke Mean'],stress_moving_avrg_O,color = 'r', alpha=0.5)
#plt.fill_between(GelMA_EGFP_SS_M['GelMA Stroke Mean'],stress_moving_avrg_E,color = 'y', alpha=0.5)


#plt.grid()
#plt.legend('OSDd2E')
#plt.title('All GelMA Stress Strain Means _ Smoothed')
#plt.xlabel('Strain Normalised')
#plt.ylabel('Stress [Pa]')
#plt.savefig("GelMA All_SS_AUC_Smoothed.png")
#plt.show()

# %%
#%matplotlib inline
#filter_length_O = 400 #red
#filter_length_S = 500 #blue
#filter_length_D = 100 #green
#filter_length_d = 5000 #lightblue
#filter_length_2 = 9000 #magenta
#filter_length_E = 4000 #yellow

#force_moving_avrg_O = np.convolve(GelMA_Only_SS_Mean['GelMA Force Mean'], np.ones((filter_length_O)),mode='same')
#force_moving_avrg_O /= filter_length_O

#force_moving_avrg_S = np.convolve(GelMA_SMPEG2_SS_M['GelMA Force Mean'], np.ones((filter_length_S)),mode='same')
#force_moving_avrg_S /= filter_length_S

#force_moving_avrg_D = np.convolve(GelMA_DHR14_SS_M['GelMA Force Mean'], np.ones((filter_length_D)),mode='same')
#force_moving_avrg_D /= filter_length_D

#force_moving_avrg_d = np.convolve(GelMA_des04c1_SS_M['GelMA Force Mean'], np.ones((filter_length_d)),mode='same')
#force_moving_avrg_d /= filter_length_d
#force_moving_avrg_2 = np.convolve(GelMA_des04c2_SS_M['GelMA Force Mean'], np.ones((filter_length_2)),mode='same')
#force_moving_avrg_2 /= filter_length_2

#force_moving_avrg_E = np.convolve(GelMA_EGFP_SS_M['GelMA Force Mean'], np.ones((filter_length_E)),mode='same')
#force_moving_avrg_E /= filter_length_E

#plt.plot(GelMA_Only_SS_Mean['GelMA Stroke Mean'],GelMA_Only_SS_Mean['GelMA Force Mean'])
#plt.plot(GelMA_Only_SS_Mean['GelMA Stroke Mean'],force_moving_avrg_O,color='r')

#plt.plot(GelMA_SMPEG2_SS_M['GelMA Stroke Mean'],GelMA_SMPEG2_SS_M['GelMA Force Mean'])
#plt.plot(GelMA_SMPEG2_SS_M['GelMA Stroke Mean'],force_moving_avrg_S,color='b')

#plt.plot(GelMA_DHR14_SS_M['GelMA Stroke Mean'],GelMA_DHR14_SS_M['GelMA Force Mean'])
#plt.plot(GelMA_DHR14_SS_M['GelMA Stroke Mean'],force_moving_avrg_D,color='g')

#plt.plot(GelMA_des04c1_SS_M['GelMA Stroke Mean'],GelMA_des04c1_SS_M['GelMA Force Mean'])
#plt.plot(GelMA_des04c1_SS_M['GelMA Stroke Mean'],force_moving_avrg_d,color='c')

#plt.plot(GelMA_des04c2_SS_M['GelMA Stroke Mean'],GelMA_des04c2_SS_M['GelMA Force Mean'])
#plt.plot(GelMA_des04c2_SS_M['GelMA Stroke Mean'],force_moving_avrg_2,color='m')

#plt.plot(GelMA_EGFP_SS_M['GelMA Stroke Mean'],GelMA_EGFP_SS_M['GelMA Force Mean'])
#plt.plot(GelMA_EGFP_SS_M['GelMA Stroke Mean'],force_moving_avrg_E,color='y')

# %% [markdown]
# # Area under the curve

# %% [markdown]
# ## Force Stroke Curves

# %%
# Datasets

#GelMA_Only_FS_Mean
#GelMA_SMPEG2_FS_M
#GelMA_DHR14_FS_M
#GelMA_des04c1_FS_M
#GelMA_des04c2_FS_M
#GelMA_EGFP_FS_M

#AUC1 = np.trapz(GelMA_Only_FS_Mean.mean()) #area_under_curve
#AUC2 = np.trapz(GelMA_SMPEG2_FS_M.mean())
#AUC3 = np.trapz(GelMA_DHR14_FS_M.mean())
#AUC4 = np.trapz(GelMA_des04c1_FS_M.mean())
#AUC5 = np.trapz(GelMA_des04c2_FS_M.mean())
#AUC6 = np.trapz(GelMA_EGFP_FS_M.mean())

#AUC_All = [[AUC1], [AUC2], [AUC3], [AUC4], [AUC5], [AUC6]]


#AUC_FS_mean = pd.DataFrame(data = AUC_All, columns=['AUC_FS_Mean'], index=['Only', 'SMPEG2','DHR14','des04c1', 'des04c2','EGFP'])

#AUC_FS_mean.to_csv('GelMA AUC_FS_mean.csv')

#AUC_FS_mean

# %%
# Datasets

#F1_only
#Strk1_only
#S1_only
#Strn1_only

####### area_under_curve

AUC1 = np.trapz(Strk1_only['Mean'], F1_only['Mean']).mean() 
AUC2 = np.trapz(Strk1_SMPEG2['Mean'], F1_SMPEG2['Mean']).mean()
AUC3 = np.trapz(Strk1_DHR14['Mean'], F1_DHR14['Mean']).mean()
AUC4 = np.trapz(Strk1_des04c1['Mean'], F1_des04c1['Mean']).mean()

AUC5 = np.trapz(Strk1_des04c2['Mean'], F1_des04c2['Mean']).mean()
AUC6 = np.trapz(Strk1_EGFP['Mean'], F1_EGFP['Mean']).mean()

#AUC5 = np.trapz(Strk1_des04c2['Mean'], F1_des04c2['Mean']).mean()
#AUC6 = np.trapz(Strk1_EGFP['Mean'], F1_EGFP['Mean']).mean()

AUC_All = [[AUC1], [AUC2], [AUC3], [AUC4], [AUC5], [AUC6]]


AUC_FS_mean = pd.DataFrame(data = AUC_All, columns=['AUC_FS_Mean'], index=['Only', 'SMPEG2','DHR14','des04c1', 'des04c2','EGFP'])

#AUC_FS_mean.to_csv('GelMA AUC_FS_mean.csv')

AUC_FS_mean
# Out:
#          AUC_FS_Mean
# Only       74.871045
# SMPEG2     46.903211
# DHR14      63.201264
# des04c1    73.841958
# des04c2    34.625837
# EGFP       32.703037

# %%
F1_only
#GelMA_Only_FS_Mean
# Out:
#        Unnamed: 0       Mean       Std     Error1     Error2
# 0               0   0.100438  0.000278   0.100160   0.100715
# 1               1   0.100533  0.000373   0.100160   0.100906
# 2               2   0.100549  0.000181   0.100368   0.100730
# 3               3   0.101598  0.000671   0.100927   0.102269
# 4               4   0.101789  0.001409   0.100380   0.103198
# ...           ...        ...       ...        ...        ...
# 20289       20289  30.595064  6.534404  24.060660  37.129468
# 20290       20290  30.599738  6.535494  24.064244  37.135232
# 20291       20291  30.604220  6.536383  24.067837  37.140603
# 20292       20292  30.608670  6.537058  24.071612  37.145728
# 20293       20293  30.613010  6.538202  24.074808  37.151212
#
# [20294 rows x 5 columns]

# %% [markdown]
# ## Stress Strain Curves

# %%
AUC7 = np.trapz(Strn1_only['Mean'], S1_only['Mean']).mean() 
AUC8 = np.trapz(Strn1_SMPEG2['Mean'], S1_SMPEG2['Mean']).mean()
AUC9 = np.trapz(Strn1_DHR14['Mean'], S1_DHR14['Mean']).mean()
AUC10 = np.trapz(Strn1_des04c1['Mean'], S1_des04c1['Mean']).mean()
AUC11 = np.trapz(Strn1_des04c2['Mean'], S1_des04c2['Mean']).mean()
AUC12 = np.trapz(Strn1_EGFP['Mean'], S1_EGFP['Mean']).mean()

AUC_All_2 = [[AUC7], [AUC8], [AUC9], [AUC10], [AUC11], [AUC12]]

AUC_All_2

AUC_SS_mean = pd.DataFrame(data = AUC_All_2, columns=['AUC_SS_Mean'], index=['Only', 'SMPEG2','DHR14','des04c1', 'des04c2','EGFP'])

#AUC_SS_mean.to_csv('GelMA AUC_SS_mean.csv')

AUC_SS_mean
# Out:
#          AUC_SS_Mean
# Only       44.794207
# SMPEG2     59.676902
# DHR14      65.346655
# des04c1    68.935642
# des04c2    24.699297
# EGFP       21.214022
